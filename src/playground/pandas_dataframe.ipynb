# %%
import pandas as pd

# %%
import numpy as np
import matplotlib as plt

# %%
plt
# Out:
# <module 'matplotlib' from '/home/nimaru/project/mol/venv/lib/python3.12/site-packages/matplotlib/__init__.py'>

# %%
np
# Out:
# <module 'numpy' from '/home/nimaru/project/mol/venv/lib/python3.12/site-packages/numpy/__init__.py'>

# %%
data = {
    'name' : ['Xavier', 'Ann', 'Jana', 'Yi', 'Robin', 'Amal', 'Nori'],
    'city' : ['Mexico City', 'Toronto', 'Prague', 'Shanghai', 'Manchester', 'Cairo', 'Osaka'],
    'age' : [41, 28, 33, 34, 38, 31, 37],
    'py-score' : [88.0, 79.0, 81.0, 80.0, 68.0, 61.0, 84.0],
}

index = range(101, 108)

# %%
df = pd.DataFrame(data, index=index)

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.index
# Out:
# RangeIndex(start=101, stop=108, step=1)

# %%
df.columns
# Out:
# Index(['name', 'city', 'age', 'py-score'], dtype='str')

# %%
df.head(10)
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
df['city']
# Out:
# 101    Mexico City
# 102        Toronto
# 103         Prague
# 104       Shanghai
# 105     Manchester
# 106          Cairo
# 107          Osaka
# Name: city, dtype: str

# %%
df.loc[103]
# Out:
# name          Jana
# city        Prague
# age             33
# py-score      81.0
# Name: 103, dtype: object

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
d = {' x': [1,2,3], 'y': np.array([2,4,8]), 'z': 100}

# %%
pd.DataFrame(d, index=[100,200,300], columns=["z","y"," x"])
# Out:
#        z  y   x
# 100  100  2   1
# 200  100  4   2
# 300  100  8   3

# %%
lst = [{"x": 1, "y": 2, "z": 100},
       {"x": 2, "y": 4, "z": 100},
       {"x": 3, "y": 8, "z": 100}]

lst2 = [[1, 2, 100],
        [2, 4, 100],
        [3, 8, 100]]

# %%
pd.DataFrame(lst)
# Out:
#    x  y    z
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
pd.DataFrame(lst2)
# Out:
#    0  1    2
# 0  1  2  100
# 1  2  4  100
# 2  3  8  100

# %%
df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
df.to_csv("job_candidate.csv")

# %%
pd.read_csv("job_candidate.csv", index_col=0)
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
df
# Out:
#        name         city  age  py-score
# 101  Xavier  Mexico City   41      88.0
# 102     Ann      Toronto   28      79.0
# 103    Jana       Prague   33      81.0
# 104      Yi     Shanghai   34      80.0
# 105   Robin   Manchester   38      68.0
# 106    Amal        Cairo   31      61.0
# 107    Nori        Osaka   37      84.0

# %%
df["py-score"].plot.hist(bins=3, alpha=0.8).savefig("plt.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df["py-score"].plot.hist(bins=3, alpha=0.8).savefig("plt.png")
#
# AttributeError: 'Axes' object has no attribute 'savefig'
