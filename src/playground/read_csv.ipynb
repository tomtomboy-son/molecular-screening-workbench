# %%
import pandas as pd

data = pd.read_csv("world_population.csv")

# %%
data
# Out:
#      Unnamed: 0                             Location    Population % of world  \
# 0             0                                World  8.232000e+09       100%
# 1             1                                India  1.429404e+09      17.3%
# 2             2                                China  1.404890e+09      17.0%
# 3             3                        United States  3.417849e+08       4.1%
# 4             4                            Indonesia  2.883151e+08       3.5%
# ..          ...                                  ...           ...        ...
# 236         236         Christmas Island (Australia)  1.692000e+03         0%
# 237         237                   Niue (New Zealand)  1.681000e+03         0%
# 238         238                         Vatican City  8.820000e+02         0%
# 239         239  Cocos (Keeling) Islands (Australia)  5.930000e+02         0%
# 240         240                Pitcairn Islands (UK)  3.500000e+01         0%
#
# ...

# %%
type(data)
# Out:
# pandas.DataFrame

# %%
data["Population"].mean()
# Out:
# np.float64(67829131.2125)

# %%
data["Population"].drop(0).mean()
# Out:
# np.float64(33669420.464435145)

# %%
data["Population"].drop(0).median()
# Out:
# np.float64(5557096.0)
